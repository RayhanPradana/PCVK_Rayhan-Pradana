# %% [markdown]
# <a href="https://colab.research.google.com/github/RayhanPradana/PCVK_Rayhan-Pradana/blob/main/PCVK_Modul_2_Rayhan_Pradana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Bahan PCVK/kitten01.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img2 =  img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)
plt.axis('off')
plt.show()

# %%
img_gray = cv.imread('/content/drive/MyDrive/Bahan PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)
plt.axis('off')
plt.show()

# %%
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_gray, cmap='magma')
plt.axis('off')
plt.show()

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)
plt.axis('off')
plt.show()

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax= fig.add_subplot(111)
ax.imshow(img5)
ax.axis('off')
plt.show()

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
cv.rectangle(black_img,pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
cv.rectangle(black_img,pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Halo dek', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %%
black_img2= np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)
plt.axis('off')
plt.show()

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)
plt.axis('off')
plt.show()
